# %%
import sys, os
from pathlib import Path
from datetime import datetime

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import numpy as np
import pandas as pd
from src.get_data import load_data
from src.train.poisson_baseline.baseline_main import (
    fit_poisson_glm,
    fit_poisson_xgboost,
)
from src.train.poisson_nn.nn_main import (
    fit_poisson_nn,
    fit_poisson_nn_transfer_learning,
)
from src.train.training import run_experiment
from src.visualisation import (
    plot_training_curves,
    plot_ytrue_vs_ypred,
    compare_models_for_cell,
    compare_r2_across_cells,  # improved version with sort_by
    compare_models_pairwise_r2,
    journal_plot_pack,  # improved version
    plot_r2_comparison_boxplot,  # NEW — main report figure
    plot_r2_histogram,  # NEW — mirrors paper Fig 3E
    plot_covariate_trial,  # NEW — Figure 1 data overview
    COVARIATE_NAMES_REAL,  # NEW — covariate name constant
)
from src.train.poisson_nn.nn_models import CNNExtractor, RNNExtractor
from sklearn.preprocessing import StandardScaler

# %%
# Real data
X, Y, cell_ids, rec_ids = load_data("../resources/data/real/Temi_Data.mat")

# %%
X.shape, Y.shape, cell_ids.shape, rec_ids.shape
# Out:
# ((14, 1657180), (1657180,), (1657180,), (1657180,))

# %%
np.unique(cell_ids).shape
# Out:
# (247,)

# %%
# ============================
# BATCH CONTROL (manual)
# ============================

CELLS_PER_BATCH = 25  # how many cells to include per run
BATCH_INDEX = 3  # manually change this: 0, 1, 2, ...

# Compute batches from the full set of cell IDs
unique_cells = np.unique(cell_ids)
batches = [
    unique_cells[i : i + CELLS_PER_BATCH]
    for i in range(0, len(unique_cells), CELLS_PER_BATCH)
]

# Select the batch you want to run
CURRENT_BATCH_CELLS = batches[BATCH_INDEX]

mask = np.isin(cell_ids, CURRENT_BATCH_CELLS)

X = X[:, mask]
Y = Y[mask]
cell_ids = cell_ids[mask]
rec_ids = rec_ids[mask]

# %%
BASE_MODEL_DIR = f"../resources/models/real/batch_{BATCH_INDEX}"
BASE_RESULTS_DIR = f"../resources/results/real/batch_{BATCH_INDEX}"
LOG_PATH = os.path.join(Path(BASE_RESULTS_DIR), f"batch_log_{BATCH_INDEX}.txt")

FORCE_EXPERIMENTS = False

# %%
def log_print(*args, **kwargs):
    """Print to console AND append to batch log file."""
    text = " ".join(str(a) for a in args)

    # Print to console
    print(text, **kwargs)

    # Append to log file
    with open(LOG_PATH, "a", encoding="utf-8") as f:
        f.write(text + "\n")

# %%
# Ensure the batch directory exists BEFORE creating the log file
os.makedirs(BASE_RESULTS_DIR, exist_ok=True)

# Create the log file only if it doesn't exist
if not os.path.exists(LOG_PATH):
    with open(LOG_PATH, "w", encoding="utf-8") as f:
        f.write(f"Batch {BATCH_INDEX} Log File\n")
        f.write(f"Created: {datetime.now()}\n")
        f.write("=" * 60 + "\n\n")

# %%
log_print(f"Running batch {BATCH_INDEX+1}/{len(batches)}")
log_print(f"Cells in this batch: {CURRENT_BATCH_CELLS}")

log_print("Filtered dataset shape:", X.shape, Y.shape)
log_print("Unique cells in this batch:", np.unique(cell_ids))
# Out:
# Running batch 4/10
# Cells in this batch: [ 76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92  93
#   94  95  96  97  98  99 100]
# Filtered dataset shape: (14, 173250) (173250,)
# Unique cells in this batch: [ 76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92  93
#   94  95  96  97  98  99 100]

# %% [markdown]
# ### Baseline models (GLM and XGBoost)

# %%
# Baseline models: Poisson GLM with grid search
glm_results = run_experiment(
    "GLM",
    fit_poisson_glm,
    {"grid_search": True, "k_folds": 5},
    X,
    Y,
    cell_ids,
    scaler=StandardScaler,
    plot=True,
    save_models=True,
    base_models_dir=BASE_MODEL_DIR,
    base_results_dir=BASE_RESULTS_DIR,
)
# Out:
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\GLM.pkl

# %%
glm_results["best_params"]
# Out:
# {76: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  77: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  78: {'model_params': {'alpha': 0.01}, 'trainer_params': {}},
#  79: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  80: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  81: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  82: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  83: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  84: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  85: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  86: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  87: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  88: {'model_params': {'alpha': 0.01}, 'trainer_params': {}},
#  89: {'model_params': {'alpha': 0.01}, 'trainer_params': {}},
#  90: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  91: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  92: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  93: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  94: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  95: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  96: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  97: {'model_params': {'alpha': 0.1}, 'trainer_params': {}},
#  98: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  99: {'model_params': {'alpha': 1.0}, 'trainer_params': {}},
#  100: {'model_params': {'alpha': 1.0}, 'trainer_params': {}}}

# %%
# Poisson XGBoost with grid search
xgboost_results = run_experiment(
    "XGBoost",
    fit_poisson_xgboost,
    {"grid_search": True, "k_folds": 5},
    X,
    Y,
    cell_ids,
    scaler=StandardScaler,
    plot=True,
    save_models=True,
    base_models_dir=BASE_MODEL_DIR,
    base_results_dir=BASE_RESULTS_DIR,
)
# Out:
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\XGBoost.pkl

# %%
xgboost_results["best_params"]
# Out:
# {76: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  77: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  78: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  79: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  80: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  81: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  82: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 4,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  83: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  84: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  85: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  86: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  87: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  88: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  89: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  90: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  91: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  92: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  93: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  94: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  95: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  96: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  97: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  98: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  99: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}},
#  100: {'model_params': {'learning_rate': 0.05,
#    'max_depth': 3,
#    'n_estimators': 200},
#   'trainer_params': {}}}

# %% [markdown]
# ### Extractor factory

# %%
def make_extractor(extractor_name, n_features, hidden_sizes):
    """
    Factory function for creating feature extractors with a unified interface.

    Parameters
    ----------
    extractor_name : str
        One of {"MLP", "CNN", "RNN"}.
    n_features : int
        Number of input features.
    hidden_sizes : int or sequence of int
        Controls the depth/width of the extractor:
        - CNN: hidden_channels per conv layer
        - RNN: hidden_sizes per GRU layer
        - MLP: ignored (returns None)

    Returns
    -------
    nn.Module or None
        The extractor module, or None for MLP-based shared layers.
    """

    if extractor_name == "CNN":
        return CNNExtractor(
            n_features=n_features,
            hidden_channels=hidden_sizes,
            kernel=3,
            dropout=0.1,
        )

    elif extractor_name == "RNN":
        return RNNExtractor(
            n_features=n_features,
            hidden_sizes=hidden_sizes,
            dropout=0.1,
        )

    elif extractor_name == "MLP":
        return None

    else:
        raise ValueError(f"Unknown extractor_name: {extractor_name}")


extractor_names = ["MLP", "CNN", "RNN"]

# %% [markdown]
# ### Per-cell Neural Networks (MLP + CNN + RNN, GS)

# %%
nn_model_param_grid_base = {
    "hidden_sizes": [
        (32,),
        (64,),
        (64, 32),
    ]
}

nn_trainer_param_grid = {
    "l1_lambda": [0.0, 1e-5, 1e-4, 1e-3],
}

percell_results = {name: {} for name in extractor_names}

# Grid-search versions
for name in extractor_names:
    print(f"\n=== Per-Cell NN (GS) with {name} extractor ===")

    # For CNN/RNN, we will build extractors inside the grid
    if name == "MLP":
        model_param_grid = nn_model_param_grid_base

    else:
        model_param_grid = {
            "extractor": [
                make_extractor(name, X.shape[0], hs)
                for hs in nn_model_param_grid_base["hidden_sizes"]
            ],
            "hidden_sizes": [None],  # ignored for CNN/RNN, but required for MLP
        }

    res = run_experiment(
        f"NN-PerCell-{name}",
        fit_poisson_nn,
        {
            "batch_size": "auto",
            "epochs": 30,
            "grid_search": True,
            "k_folds": 2,
            "model_param_grid": model_param_grid,
            "trainer_param_grid": nn_trainer_param_grid,
        },
        X,
        Y,
        cell_ids,
        scaler=StandardScaler,
        plot=True,
        save_models=True,
        force=FORCE_EXPERIMENTS,
        base_models_dir=BASE_MODEL_DIR,
        base_results_dir=BASE_RESULTS_DIR,
    )

    percell_results[name]["GS"] = res
# Out:
# === Per-Cell NN (GS) with MLP extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-PerCell-MLP.pkl
#
# === Per-Cell NN (GS) with CNN extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-PerCell-CNN.pkl
#
# === Per-Cell NN (GS) with RNN extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-PerCell-RNN.pkl
# c:\Users\Temitope Shitta\miniconda3\envs\res_proj_1\Lib\site-packages\torch\nn\modules\rnn.py:1334: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   super().__init__("GRU", *args, **kwargs)

# %%
tl_results = {
    "deep_shared_shallow_head": {name: {} for name in extractor_names},
    "deep_shared_deep_head": {name: {} for name in extractor_names},
    "shallow_shared_deep_head": {name: {} for name in extractor_names},
}

# %% [markdown]
# ### Transfer Learning: deep shared hidden and shallow cell-specific heads (MLP + CNN + RNN, GS)

# %%
# Updated hidden-size grid for deep shared extractor
tl_deep_shared_shallow_head_model_param_grid_base = {
    "hidden_sizes": [
        (128,),
        (256,),
        (128, 64),
        (256, 128),
    ]
}

tl_deep_shared_shallow_head_trainer_param_grid = {
    "l1_lambda": [0.0, 1e-5, 1e-4],
}

# Shared hidden: GS
for name in extractor_names:
    print(f"\n=== TL DeepSharedShallowHead (GS) with {name} extractor ===")

    # Build extractor using unified hidden_sizes interface
    # For CNN/RNN: hidden_sizes define extractor depth
    # For MLP: extractor = None
    extractor_list = []
    for hs in tl_deep_shared_shallow_head_model_param_grid_base["hidden_sizes"]:
        extractor_list.append(
            make_extractor(extractor_name=name, n_features=X.shape[0], hidden_sizes=hs)
        )

    if name == "MLP":
        # MLP baseline: no extractor, hidden_sizes define shared MLP
        model_param_grid = {
            "hidden_sizes": tl_deep_shared_shallow_head_model_param_grid_base[
                "hidden_sizes"
            ],
            "shared_extractor": [None],
        }
    else:
        # CNN/RNN: extractor replaces shared MLP
        model_param_grid = {
            "hidden_sizes": [None],  # ignored for CNN/RNN, but required for MLP
            "shared_extractor": extractor_list,
        }

    res = run_experiment(
        f"NN-DeepSharedShallowHead-TL-{name}",
        fit_poisson_nn_transfer_learning,
        {
            "batch_size": "auto",
            "grid_search": True,
            "model_param_grid": model_param_grid,
            "trainer_param_grid": tl_deep_shared_shallow_head_trainer_param_grid,
        },
        X,
        Y,
        cell_ids,
        scaler=StandardScaler,
        plot=True,
        save_models=True,
        force=FORCE_EXPERIMENTS,
        base_models_dir=BASE_MODEL_DIR,
        base_results_dir=BASE_RESULTS_DIR,
    )

    tl_results["deep_shared_shallow_head"][name]["GS"] = res
# Out:
# === TL DeepSharedShallowHead (GS) with MLP extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-DeepSharedShallowHead-TL-MLP.pkl
#
# === TL DeepSharedShallowHead (GS) with CNN extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-DeepSharedShallowHead-TL-CNN.pkl
#
# === TL DeepSharedShallowHead (GS) with RNN extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-DeepSharedShallowHead-TL-RNN.pkl

# %% [markdown]
# ### Transfer Learning: deep shared hidden and deep cell-specific heads (MLP + CNN + RNN, GS)

# %%
tl_deep_shared_deep_head_model_param_grid_base = {
    "shared_sizes": [
        (128,),
        (256,),
        (128, 64),
        (256, 128),
    ],
    "head_sizes": [
        (64, 32),
        (128, 64),
        (256, 128),
    ],
}

tl_deep_shared_deep_head_trainer_param_grid = {
    "l1_lambda": [0.0, 1e-5, 1e-4],
}

# Nonlinear heads: GS
for name in extractor_names:
    print(f"\n=== TL DeepSharedDeepHead (GS) with {name} extractor ===")

    # Build extractors for each shared_sizes configuration
    extractor_list = []
    for shared_sizes in tl_deep_shared_deep_head_model_param_grid_base["shared_sizes"]:
        extractor_list.append(
            make_extractor(
                extractor_name=name, n_features=X.shape[0], hidden_sizes=shared_sizes
            )
        )

    if name == "MLP":
        # MLP baseline: shared MLP uses shared_sizes directly
        model_param_grid = {
            "shared_sizes": tl_deep_shared_deep_head_model_param_grid_base[
                "shared_sizes"
            ],
            "head_sizes": tl_deep_shared_deep_head_model_param_grid_base["head_sizes"],
            "shared_extractor": [None],
        }

    else:
        # CNN/RNN: extractor replaces shared MLP
        model_param_grid = {
            "shared_extractor": extractor_list,
            "head_sizes": tl_deep_shared_deep_head_model_param_grid_base["head_sizes"],
            "shared_sizes": [None],  # ignored for CNN/RNN, but required for MLP
        }

    res = run_experiment(
        f"NN-DeepSharedDeepHead-TL-{name}",
        fit_poisson_nn_transfer_learning,
        {
            "batch_size": "auto",
            "grid_search": True,
            "model_type": "deep_shared_deep_head",
            "model_param_grid": model_param_grid,
            "trainer_param_grid": tl_deep_shared_deep_head_trainer_param_grid,
        },
        X,
        Y,
        cell_ids,
        scaler=StandardScaler,
        plot=True,
        save_models=True,
        force=FORCE_EXPERIMENTS,
        base_models_dir=BASE_MODEL_DIR,
        base_results_dir=BASE_RESULTS_DIR,
    )

    tl_results["deep_shared_deep_head"][name]["GS"] = res
# Out:
# === TL DeepSharedDeepHead (GS) with MLP extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-DeepSharedDeepHead-TL-MLP.pkl
#
# === TL DeepSharedDeepHead (GS) with CNN extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-DeepSharedDeepHead-TL-CNN.pkl
#
# === TL DeepSharedDeepHead (GS) with RNN extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-DeepSharedDeepHead-TL-RNN.pkl

# %% [markdown]
# ### Transfer Learning: shallow shared hidden and deep cell-specific heads (MLP + CNN + RNN, GS)

# %%
tl_shallow_shared_deep_head_model_param_grid_base = {
    "shared_dim": [128, 256],
    "head_sizes": [
        (64, 32),
        (128, 64),
        (256, 128),
    ],
}

tl_shallow_shared_deep_head_trainer_param_grid = {
    "l1_lambda": [0.0, 1e-5, 1e-4],
}

# First layer: GS
for name in extractor_names:
    print(f"\n=== TL ShallowSharedDeepHead (GS) with {name} extractor ===")

    # Build extractors for each shared_dim
    extractor_list = []
    for sd in tl_shallow_shared_deep_head_model_param_grid_base["shared_dim"]:
        extractor_list.append(
            make_extractor(
                extractor_name=name,
                n_features=X.shape[0],
                hidden_sizes=(sd,),  # shallow extractor = 1 layer
            )
        )

    if name == "MLP":
        # MLP baseline: shallow shared layer is Linear(n_features → shared_dim)
        model_param_grid = {
            "shared_dim": tl_shallow_shared_deep_head_model_param_grid_base[
                "shared_dim"
            ],
            "head_sizes": tl_shallow_shared_deep_head_model_param_grid_base[
                "head_sizes"
            ],
            "shared_extractor": [None],
        }

    else:
        # CNN/RNN: extractor replaces shallow Linear layer
        model_param_grid = {
            "shared_dim": [None],  # ignored for CNN/RNN, but required for MLP
            "head_sizes": tl_shallow_shared_deep_head_model_param_grid_base[
                "head_sizes"
            ],
            "shared_extractor": extractor_list,
        }

    res = run_experiment(
        f"NN-ShallowSharedDeepHead-TL-{name}",
        fit_poisson_nn_transfer_learning,
        {
            "batch_size": "auto",
            "grid_search": True,
            "model_type": "shallow_shared_deep_head",
            "model_param_grid": model_param_grid,
            "trainer_param_grid": tl_shallow_shared_deep_head_trainer_param_grid,
        },
        X,
        Y,
        cell_ids,
        scaler=StandardScaler,
        plot=True,
        save_models=True,
        force=FORCE_EXPERIMENTS,
        base_models_dir=BASE_MODEL_DIR,
        base_results_dir=BASE_RESULTS_DIR,
    )

    tl_results["shallow_shared_deep_head"][name]["GS"] = res
# Out:
# === TL ShallowSharedDeepHead (GS) with MLP extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-ShallowSharedDeepHead-TL-MLP.pkl
#
# === TL ShallowSharedDeepHead (GS) with CNN extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-ShallowSharedDeepHead-TL-CNN.pkl
#
# === TL ShallowSharedDeepHead (GS) with RNN extractor ===
# [run_experiment] Loading cached results from ..\resources\models\real\batch_3\NN-ShallowSharedDeepHead-TL-RNN.pkl

# %%
print("MLP\n", percell_results["MLP"]["GS"]["best_params"])
print("CNN\n", percell_results["CNN"]["GS"]["best_params"])
print("RNN\n", percell_results["RNN"]["GS"]["best_params"])
# Out:
# MLP
#  {76: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 77: {'model_params': {'hidden_sizes': (32,)}, 'trainer_params': {'l1_lambda': 0.001}}, 78: {'model_params': {'hidden_sizes': (64,)}, 'trainer_params': {'l1_lambda': 0.001}}, 79: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 80: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 81: {'model_params': {'hidden_sizes': (64,)}, 'trainer_params': {'l1_lambda': 0.001}}, 82: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 83: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.0001}}, 84: {'model_params': {'hidden_sizes': (32,)}, 'trainer_params': {'l1_lambda': 0.001}}, 85: {'model_params': {'hidden_sizes': (64,)}, 'trainer_params': {'l1_lambda': 1e-05}}, 86: {'model_params': {'hidden_sizes': (64,)}, 'trainer_params': {'l1_lambda': 0.001}}, 87: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 88: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 89: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 90: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 91: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 92: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 93: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 94: {'model_params': {'hidden_sizes': (32,)}, 'trainer_params': {'l1_lambda': 0.0001}}, 95: {'model_params': {'hidden_sizes': (32,)}, 'trainer_params': {'l1_lambda': 0.0001}}, 96: {'model_params': {'hidden_sizes': (64,)}, 'trainer_params': {'l1_lambda': 0.001}}, 97: {'model_params': {'hidden_sizes': (32,)}, 'trainer_params': {'l1_lambda': 0.001}}, 98: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}, 99: {'model_params': {'hidden_sizes': (32,)}, 'trainer_params': {'l1_lambda': 0.001}}, 100: {'model_params': {'hidden_sizes': (64, 32)}, 'trainer_params': {'l1_lambda': 0.001}}}
# CNN
#  {76: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 77: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 78: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0}}, 79: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 80: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 81: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 82: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 83: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 84: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 1e-05}}, 85: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 86: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 87: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 88: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 89: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 90: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 91: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 1e-05}}, 92: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 93: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 94: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0}}, 95: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 96: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 97: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 1e-05}}, 98: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 99: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 100: {'model_params': {'extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(64, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): ReLU()
#   )
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}}
# RNN
#  {76: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 77: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 78: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#     (1): GRU(64, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 79: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 80: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 81: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#     (1): GRU(64, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 82: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 83: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 84: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 85: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 1e-05}}, 86: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0}}, 87: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0}}, 88: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 89: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 90: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 91: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#     (1): GRU(64, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 92: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 93: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0}}, 94: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#     (1): GRU(64, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0001}}, 95: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#     (1): GRU(64, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.0}}, 96: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#     (1): GRU(64, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 97: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#     (1): GRU(64, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 1e-05}}, 98: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 99: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 64, batch_first=True, dropout=0.1)
#     (1): GRU(64, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}, 100: {'model_params': {'extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 32, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
# ), 'hidden_sizes': None}, 'trainer_params': {'l1_lambda': 0.001}}}

# %%
print("MLP\n", tl_results["deep_shared_shallow_head"]["MLP"]["GS"]["best_params"])
print("CNN\n", tl_results["deep_shared_shallow_head"]["CNN"]["GS"]["best_params"])
print("RNN\n", tl_results["deep_shared_shallow_head"]["RNN"]["GS"]["best_params"])
# Out:
# MLP
#  {'model_params': {'hidden_sizes': (256, 128), 'shared_extractor': None}, 'trainer_params': {'l1_lambda': 0.0}}
# CNN
#  {'model_params': {'hidden_sizes': None, 'shared_extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#   )
# )}, 'trainer_params': {'l1_lambda': 0.0}}
# RNN
#  {'model_params': {'hidden_sizes': None, 'shared_extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 128, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
# )}, 'trainer_params': {'l1_lambda': 0.0}}

# %%
print("MLP\n", tl_results["deep_shared_deep_head"]["MLP"]["GS"]["best_params"])
print("CNN\n", tl_results["deep_shared_deep_head"]["CNN"]["GS"]["best_params"])
print("RNN\n", tl_results["deep_shared_deep_head"]["RNN"]["GS"]["best_params"])
# Out:
# MLP
#  {'model_params': {'head_sizes': (128, 64), 'shared_extractor': None, 'shared_sizes': (256, 128)}, 'trainer_params': {'l1_lambda': 1e-05}}
# CNN
#  {'model_params': {'head_sizes': (256, 128), 'shared_extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv1d(256, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#   )
# ), 'shared_sizes': None}, 'trainer_params': {'l1_lambda': 1e-05}}
# RNN
#  {'model_params': {'head_sizes': (256, 128), 'shared_extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 128, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
# ), 'shared_sizes': None}, 'trainer_params': {'l1_lambda': 1e-05}}

# %%
print("MLP\n", tl_results["shallow_shared_deep_head"]["MLP"]["GS"]["best_params"])
print("CNN\n", tl_results["shallow_shared_deep_head"]["CNN"]["GS"]["best_params"])
print("RNN\n", tl_results["shallow_shared_deep_head"]["RNN"]["GS"]["best_params"])
# Out:
# MLP
#  {'model_params': {'head_sizes': (256, 128), 'shared_dim': 128, 'shared_extractor': None}, 'trainer_params': {'l1_lambda': 1e-05}}
# CNN
#  {'model_params': {'head_sizes': (256, 128), 'shared_dim': None, 'shared_extractor': CNNExtractor(
#   (conv): Sequential(
#     (0): Conv1d(1, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
#   (adapter): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#   )
# )}, 'trainer_params': {'l1_lambda': 1e-05}}
# RNN
#  {'model_params': {'head_sizes': (256, 128), 'shared_dim': None, 'shared_extractor': RNNExtractor(
#   (rnns): ModuleList(
#     (0): GRU(1, 256, batch_first=True, dropout=0.1)
#   )
#   (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
# )}, 'trainer_params': {'l1_lambda': 1e-05}}

# %% [markdown]
# ### Build comparison lists for GS

# %%
# Grid search results for all models
model_results_gs = [
    (glm_results["results"], "GLM"),
    (xgboost_results["results"], "XGBoost"),
    (percell_results["MLP"]["GS"]["results"], "NN-PerCell-MLP"),
    (percell_results["CNN"]["GS"]["results"], "NN-PerCell-CNN"),
    (percell_results["RNN"]["GS"]["results"], "NN-PerCell-RNN"),
    (
        tl_results["deep_shared_shallow_head"]["MLP"]["GS"]["results"],
        "NN-DeepSharedShallowHead-TL-MLP",
    ),
    (
        tl_results["deep_shared_shallow_head"]["CNN"]["GS"]["results"],
        "NN-DeepSharedShallowHead-TL-CNN",
    ),
    (
        tl_results["deep_shared_shallow_head"]["RNN"]["GS"]["results"],
        "NN-DeepSharedShallowHead-TL-RNN",
    ),
    (
        tl_results["deep_shared_deep_head"]["MLP"]["GS"]["results"],
        "NN-DeepSharedDeepHead-TL-MLP",
    ),
    (
        tl_results["deep_shared_deep_head"]["CNN"]["GS"]["results"],
        "NN-DeepSharedDeepHead-TL-CNN",
    ),
    (
        tl_results["deep_shared_deep_head"]["RNN"]["GS"]["results"],
        "NN-DeepSharedDeepHead-TL-RNN",
    ),
    (
        tl_results["shallow_shared_deep_head"]["MLP"]["GS"]["results"],
        "NN-ShallowSharedDeepHead-TL-MLP",
    ),
    (
        tl_results["shallow_shared_deep_head"]["CNN"]["GS"]["results"],
        "NN-ShallowSharedDeepHead-TL-CNN",
    ),
    (
        tl_results["shallow_shared_deep_head"]["RNN"]["GS"]["results"],
        "NN-ShallowSharedDeepHead-TL-RNN",
    ),
]

cells_gs = sorted(glm_results["results"].keys())

# %%
data_rows = []
for cell in cells_gs:
    row = {"cell": cell}
    for results, name in model_results_gs:
        row[name] = results[cell]["test"]["pseudo_r2"]
    data_rows.append(row)

df_test_perf_gs = pd.DataFrame(data_rows)
df_test_perf_gs
# Out:
#     cell       GLM   XGBoost  NN-PerCell-MLP  NN-PerCell-CNN  NN-PerCell-RNN  \
# 0     76  0.013660  0.006687       -0.003544        0.006875       -0.011831
# 1     77 -0.006875  0.137991        0.078863        0.021860       -0.009252
# 2     78  0.018699  0.010155        0.021020        0.011872       -0.004543
# 3     79 -0.046010 -0.088144        0.003061        0.006360       -0.005209
# 4     80  0.014908  0.006620        0.014112        0.020653       -0.000212
# 5     81  0.031015  0.011559        0.013400       -0.000382        0.057402
# 6     82  0.001107 -0.005446        0.060982        0.022563       -0.074817
# 7     83  0.045161  0.045110        0.069265       -0.010107        0.069345
# 8     84  0.022581  0.011476        0.002348        0.008091        0.006510
# 9     85  0.027899  0.131197        0.103427        0.074117        0.070105
# 10    86  0.064899  0.072531        0.071807        0.063016        0.057654
# 11    87  0.034009  0.024715        0.034182        0.040527        0.033719
# 12    88  0.020628  0.060708        0.038139       -0.008052        0.014321
# 13    89  0.173771  0.192017        0.233902       -0.006962        0.156017
# 14    90  0.003958 -0.031181       -0.002486       -0.010380       -0.010376
# 15    91  0.047088  0.085933        0.086671        0.087258        0.070654
# 16    92 -0.009013 -0.027705       -0.009145       -0.000860       -0.040497
# 17    93  0.042326  0.150802        0.164331       -0.015165        0.108010
# 18    94  0.034118  0.036336        0.040669        0.036346        0.030300
# 19    95  0.027344  0.044062        0.033658        0.008651        0.009529
# 20    96  0.081498  0.125635        0.099696       -0.000034        0.090832
# 21    97  0.003292 -0.043612       -0.055454       -0.038674       -0.048778
# 22    98 -0.027949  0.088920       -0.039661       -0.024821       -0.026939
# 23    99 -0.001087 -0.002339       -0.005460       -0.000155       -0.000525
# 24   100 -0.001328 -0.041336       -0.047772       -0.004013       -0.003943
#
#     NN-DeepSharedShallowHead-TL-MLP  NN-DeepSharedShallowHead-TL-CNN  \
# 0                          0.019532                         0.032699
# 1                          0.112477                         0.139819
# 2                          0.004968                         0.015444
# 3                         -0.009802                        -0.005765
# 4                          0.019562                         0.024843
# 5                          0.043625                         0.059386
# 6                          0.021127                         0.027195
# 7                          0.070755                         0.075285
# 8                          0.000438                         0.034955
# 9                          0.141114                         0.088516
# 10                         0.066605                         0.056064
# 11                         0.006118                         0.058400
# 12                         0.036286                         0.028808
# 13                         0.119698                         0.108189
# 14                         0.014874                        -0.002699
# 15                         0.094384                         0.091135
# 16                        -0.002940                        -0.005005
# 17                         0.118849                         0.091405
# 18                         0.060950                         0.069656
# 19                         0.040120                         0.078033
# 20                         0.124799                         0.122195
# 21                        -0.020330                        -0.031433
# 22                        -0.026094                        -0.014752
# 23                        -0.014716                         0.002272
# 24                        -0.035497                        -0.022906
#
#     NN-DeepSharedShallowHead-TL-RNN  NN-DeepSharedDeepHead-TL-MLP  \
# 0                          0.031886                      0.024202
# 1                          0.098742                      0.124488
# 2                          0.009922                      0.005663
# 3                         -0.014623                     -0.005517
# 4                          0.024299                      0.023375
# 5                          0.062688                      0.053642
# 6                         -0.008911                      0.034687
# 7                          0.060712                      0.073324
# 8                          0.026007                      0.005261
# 9                          0.053506                      0.136847
# 10                         0.036670                      0.060281
# 11                         0.026878                      0.031333
# 12                         0.028833                      0.031746
# 13                         0.104314                      0.146374
# 14                        -0.002525                      0.009175
# 15                         0.062890                      0.079805
# 16                        -0.026931                     -0.008266
# 17                         0.050728                      0.119297
# 18                         0.052630                      0.059717
# 19                         0.055763                      0.036202
# 20                         0.117080                      0.114982
# 21                        -0.024645                     -0.041594
# 22                        -0.001093                     -0.020997
# 23                        -0.007773                     -0.002740
# 24                        -0.002368                     -0.024364
#
#     NN-DeepSharedDeepHead-TL-CNN  NN-DeepSharedDeepHead-TL-RNN  \
# 0                       0.027567                      0.033026
# 1                       0.148837                      0.125042
# 2                       0.015986                      0.008252
# 3                      -0.018921                      0.002543
# 4                       0.028705                      0.024557
# 5                       0.058178                      0.060080
# 6                       0.022778                      0.060319
# 7                       0.076813                      0.074013
# 8                       0.015186                      0.021289
# 9                       0.088161                      0.058586
# 10                      0.051633                      0.043728
# 11                      0.049025                      0.022751
# 12                      0.032997                      0.028399
# 13                      0.117924                      0.173325
# 14                      0.009397                     -0.003194
# 15                      0.072446                      0.058883
# 16                     -0.014574                     -0.012064
# 17                      0.134888                     -0.002119
# 18                      0.073679                      0.056923
# 19                      0.041006                      0.064779
# 20                      0.120652                      0.114674
# 21                     -0.008876                     -0.044236
# 22                     -0.009751                      0.006644
# 23                     -0.007379                     -0.001806
# 24                     -0.032263                     -0.048048
#
#     NN-ShallowSharedDeepHead-TL-MLP  NN-ShallowSharedDeepHead-TL-CNN  \
# 0                          0.028017                         0.033222
# 1                          0.132698                         0.108189
# 2                          0.005506                         0.011703
# 3                         -0.004087                         0.000315
# 4                          0.021685                         0.024267
# 5                          0.050116                         0.064361
# 6                          0.045728                         0.026727
# 7                          0.065355                         0.065779
# 8                          0.006022                         0.015206
# 9                          0.144740                         0.066224
# 10                         0.063281                         0.044573
# 11                         0.031105                         0.031311
# 12                         0.029870                         0.020355
# 13                         0.185687                         0.079784
# 14                         0.013113                        -0.022877
# 15                         0.079153                         0.075198
# 16                        -0.006875                        -0.011030
# 17                         0.101160                         0.040895
# 18                         0.052562                         0.054301
# 19                         0.047778                         0.061563
# 20                         0.133344                         0.103812
# 21                        -0.027085                        -0.021159
# 22                        -0.018178                        -0.005932
# 23                        -0.005022                        -0.006112
# 24                        -0.049097                        -0.029343
#
#     NN-ShallowSharedDeepHead-TL-RNN
# 0                          0.037020
# 1                          0.113234
# 2                          0.004837
# 3                          0.003760
# 4                          0.027904
# 5                          0.066601
# 6                          0.043315
# 7                          0.073837
# 8                          0.033417
# 9                          0.055141
# 10                         0.052732
# 11                         0.021520
# 12                         0.026865
# 13                         0.166197
# 14                        -0.004554
# 15                         0.058752
# 16                        -0.009500
# 17                         0.052070
# 18                         0.053794
# 19                         0.062260
# 20                         0.109718
# 21                        -0.045305
# 22                        -0.003332
# 23                        -0.004634
# 24                        -0.034962

# %%
from src.statistical_analysis_cell import summarise_and_test

batch_summary = summarise_and_test(
    df=df_test_perf_gs,
    base_results_dir=BASE_RESULTS_DIR,
    batch_index=BATCH_INDEX,
)
# Out:
# ================================================================================
# BATCH 3 — SUMMARY STATISTICS (25 cells)
# ================================================================================
# Model                                       Median    Mean  IQR lo  IQR hi    %>0   N>0
# ----------------------------------------------------------------------------------
# GLM                                         0.0206  0.0246  0.0011  0.0341    76%    19
# XGBoost                                     0.0247  0.0401 -0.0023  0.0859    72%    18
# NN-PerCell-MLP                              0.0337  0.0402 -0.0025  0.0718    72%    18
# NN-PerCell-CNN                              0.0064  0.0115 -0.0070  0.0219    52%    13
# NN-PerCell-RNN                              0.0065  0.0215 -0.0093  0.0577    52%    13
# NN-DeepSharedShallowHead-TL-MLP             0.0211  0.0403  0.0004  0.0708    76%    19
# NN-DeepSharedShallowHead-TL-CNN             0.0350  0.0449  0.0023  0.0780    76%    19
# NN-DeepSharedShallowHead-TL-RNN             0.0288  0.0326 -0.0024  0.0558    68%    17
# NN-DeepSharedDeepHead-TL-MLP                0.0317  0.0427  0.0053  0.0733    76%    19
# NN-DeepSharedDeepHead-TL-CNN                0.0330  0.0438  0.0094  0.0737    76%    19
# NN-DeepSharedDeepHead-TL-RNN                0.0284  0.0371  0.0025  0.0601    76%    19
# NN-ShallowSharedDeepHead-TL-MLP             0.0311  0.0451  0.0055  0.0654    76%    19
# NN-ShallowSharedDeepHead-TL-CNN             0.0313  0.0333  0.0003  0.0644    76%    19
# NN-ShallowSharedDeepHead-TL-RNN             0.0370  0.0384  0.0038  0.0588    76%    19
#
# ================================================================================
# WILCOXON SIGNED-RANK TESTS vs GLM (one-sided: model > GLM)
# ================================================================================
# Model                                       statistic    p-value      sig
# ------------------------------------------------------------------------
# XGBoost                                         180.0     0.3264       ns
# NN-PerCell-MLP                                  222.0     0.0567       ns
# NN-PerCell-CNN                                  121.0     0.8683       ns
# NN-PerCell-RNN                                  133.0     0.7869       ns
# NN-DeepSharedShallowHead-TL-MLP                 222.0     0.0567       ns
# NN-DeepSharedShallowHead-TL-CNN                 263.0     0.0028       **
# NN-DeepSharedShallowHead-TL-RNN                 220.0     0.0633       ns
# NN-DeepSharedDeepHead-TL-MLP                    241.0     0.0171        *
# NN-DeepSharedDeepHead-TL-CNN                    258.0     0.0044       **
# NN-DeepSharedDeepHead-TL-RNN                    218.0     0.0705       ns
# NN-ShallowSharedDeepHead-TL-MLP                 257.0     0.0048       **
# NN-ShallowSharedDeepHead-TL-CNN                 212.0     0.0954       ns
# NN-ShallowSharedDeepHead-TL-RNN                 240.0     0.0183        *
#
# ================================================================================
# WILCOXON SIGNED-RANK TESTS vs NN-PerCell-MLP (one-sided: TL > MLP)
# ================================================================================
# Model                                       statistic    p-value      sig
# ------------------------------------------------------------------------
# NN-DeepSharedShallowHead-TL-MLP                 193.0     0.2131       ns
# NN-DeepSharedShallowHead-TL-CNN                 216.0     0.0782       ns
# NN-DeepSharedShallowHead-TL-RNN                 156.0     0.5734       ns
# NN-DeepSharedDeepHead-TL-MLP                    204.0     0.1376       ns
# NN-DeepSharedDeepHead-TL-CNN                    201.0     0.1562       ns
# NN-DeepSharedDeepHead-TL-RNN                    177.0     0.3556       ns
# NN-ShallowSharedDeepHead-TL-MLP                 200.0     0.1627       ns
# NN-ShallowSharedDeepHead-TL-CNN                 163.0     0.5000       ns
# NN-ShallowSharedDeepHead-TL-RNN                 174.0     0.3856       ns
#
# ================================================================================
# MODEL RANKING BY MEDIAN PSEUDO-R² (batch 3)
# ================================================================================
#    1. NN-ShallowSharedDeepHead-TL-RNN            0.0370  (76% above chance)
#    2. NN-DeepSharedShallowHead-TL-CNN            0.0350  (76% above chance)
#    3. NN-PerCell-MLP                             0.0337  (72% above chance)
#    4. NN-DeepSharedDeepHead-TL-CNN               0.0330  (76% above chance)
#    5. NN-DeepSharedDeepHead-TL-MLP               0.0317  (76% above chance)
#    6. NN-ShallowSharedDeepHead-TL-CNN            0.0313  (76% above chance)
#    7. NN-ShallowSharedDeepHead-TL-MLP            0.0311  (76% above chance)
#    8. NN-DeepSharedShallowHead-TL-RNN            0.0288  (68% above chance)
#    9. NN-DeepSharedDeepHead-TL-RNN               0.0284  (76% above chance)
#   10. XGBoost                                    0.0247  (72% above chance)
#   11. NN-DeepSharedShallowHead-TL-MLP            0.0211  (76% above chance)
#   12. GLM                                        0.0206  (76% above chance)
#   13. NN-PerCell-RNN                             0.0065  (52% above chance)
#   14. NN-PerCell-CNN                             0.0064  (52% above chance)
#
# Summary statistics saved to ..\resources\results\real\batch_3\batch_3_summary_stats.csv
# Wilcoxon (vs GLM) results saved to ..\resources\results\real\batch_3\batch_3_wilcoxon_vs_glm.csv
# Wilcoxon (vs MLP) results saved to ..\resources\results\real\batch_3\batch_3_wilcoxon_vs_mlp.csv

# %%
compare_models_for_cell(model_results_gs, cell=90, split="test")

# %%
compare_r2_across_cells(model_results_gs, split="test")

# %%
compare_models_pairwise_r2(
    model_results_gs,
    "NN-PerCell-MLP",
    "NN-PerCell-CNN",
)

# %%
# For journal_plot_pack, pass only the 4 key models for the summary outputs
# The full-model comparisons come from the dedicated figure cells above
key_models_for_pack = [
    (glm_results["results"], "GLM"),
    (xgboost_results["results"], "XGBoost"),
    (percell_results["MLP"]["GS"]["results"], "NN-PerCell-MLP"),
    (
        tl_results["deep_shared_deep_head"]["MLP"]["GS"]["results"],
        "NN-DeepSharedDeepHead-TL-MLP",
    ),
]

saved_paths = journal_plot_pack(
    key_models_for_pack,  # 4 models only
    cells=cells_gs,
    split="test",
    base_dir=BASE_RESULTS_DIR,
    pairwise_pairs=[
        ("GLM", "NN-PerCell-MLP"),
        ("GLM", "NN-DeepSharedDeepHead-TL-MLP"),
        ("NN-PerCell-MLP", "NN-DeepSharedDeepHead-TL-MLP"),
    ],
    example_cells=[90],
)

log_print(f"Generated {len(saved_paths)} plots")
for p in saved_paths[-5:]:
    log_print(f"  {p}")
# Out:
# Generated 7 plots
#   ..\resources\results\real\batch_3\journal\r2_line.png
#   ..\resources\results\real\batch_3\journal\pairwise_GLM_vs_NN-PerCell-MLP.png
#   ..\resources\results\real\batch_3\journal\pairwise_GLM_vs_NN-DeepSharedDeepHead-TL-MLP.png
#   ..\resources\results\real\batch_3\journal\pairwise_NN-PerCell-MLP_vs_NN-DeepSharedDeepHead-TL-MLP.png
#   ..\resources\results\real\batch_3\journal\cell_90.png

# %%
# Figure 1 panel: covariate time-series for one example trial
# Cell 6, trial 50 is a good choice — cell 6 has the highest pseudo-R²
# in batch 0 and trial 50 is well into the session where tilt events occur
fig_cov = plot_covariate_trial(
    X,
    Y,
    cell_ids,
    cell_idx=90,
    trial_idx=150,  # pick a mid-session tilt trial
    covariate_names=COVARIATE_NAMES_REAL,
    trials_per_cell=400,
    bin_duration_ms=50,
    show_only_indices=[0, 1, 2, 3, 4],  # motion covariates only
    figsize=(8, 6),  # explicit size: compact and readable
    title="Example trial: motion covariates and spike counts (Cell 90)",
)

# Save at 300 DPI for print-quality output
from src.train.io import save_plot

save_plot(fig_cov, "journal", "figure1_covariate_trial.png", base_dir=BASE_RESULTS_DIR)
fig_cov.savefig(
    f"{BASE_RESULTS_DIR}/journal/figure1_covariate_trial.pdf",
    dpi=300,
    bbox_inches="tight",
)

# %%
# Figure 5: model comparison box plot for real data (batch 0)
fig_box = plot_r2_comparison_boxplot(
    model_results_gs,
    split="test",
    title=f"Batch 1 (cells 76-100): test pseudo-R² by model",
    rotate_labels=True,
)
save_plot(fig_box, "journal", "figure5_r2_boxplot.png", base_dir=BASE_RESULTS_DIR)
# Out:
# WindowsPath('../resources/results/real/batch_3/journal/figure5_r2_boxplot.png')

# %%
# Companion histogram — mirrors Figure 3E of Ebrahimi et al. (2025)
# Include only the key models for a clean comparison
key_models = [
    (glm_results["results"], "GLM"),
    (xgboost_results["results"], "XGBoost"),
    (percell_results["MLP"]["GS"]["results"], "NN-PerCell-MLP"),
    (
        tl_results["deep_shared_deep_head"]["MLP"]["GS"]["results"],
        "NN-DeepSharedDeepHead-TL-MLP",
    ),
]
fig_hist = plot_r2_histogram(
    key_models,
    split="test",
    title="Distribution of test pseudo-R² across cells (batch 3)",
)
save_plot(fig_hist, "journal", "figure5_r2_histogram.png", base_dir=BASE_RESULTS_DIR)
# Out:
# WindowsPath('../resources/results/real/batch_3/journal/figure5_r2_histogram.png')

# %%
# Exploratory: sort cells by GLM performance to see cross-model patterns
fig_line = compare_r2_across_cells(
    model_results_gs,
    split="test",
    sort_by="GLM",  # reorder cells from hardest to easiest for the GLM
)
save_plot(fig_line, "journal", "r2_sorted_by_glm.png", base_dir=BASE_RESULTS_DIR)
# Out:
# WindowsPath('../resources/results/real/batch_3/journal/r2_sorted_by_glm.png')
