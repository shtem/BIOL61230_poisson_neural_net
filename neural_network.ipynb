# %%
# POISSON NN
# https://jamesmccaffreyblog.com/2025/02/20/poisson-neural-network-using-pytorch-with-poissonnllloss/
# https://jamesmccaffreyblog.com/2025/02/04/predicting-poisson-distributed-target-data-pytorch-neural-network-vs-scikit-poissonregressor/
# https://docs.pytorch.org/docs/stable/generated/torch.nn.PoissonNLLLoss.html

# BASIC NN IN PYTORCH
# https://machinelearningmastery.com/develop-your-first-neural-network-with-pytorch-step-by-step/
